# %% [markdown]
# BISHWAGIT DAS,ID:18-36730-1,SEC: F,WEEK 2

# %% [markdown]
# **Lesson-3(Lists)**

# %%
L1 = []
L2 = [11, 15, 20, 25]
L3 = ['ab', ['bc', 'ca']]

# %%
L2[2]
# Out:
# 20

# %%
L3[1][0]
# Out:
# 'bc'

# %%
L2[1:2]
# Out:
# [15]

# %%
len(L2)
# Out:
# 4

# %%
L1 + L2
# Out:
# [11, 15, 20, 25]

# %%
L2 * 4
# Out:
# [11, 15, 20, 25, 11, 15, 20, 25, 11, 15, 20, 25, 11, 15, 20, 25]

# %% [markdown]
# Basic List Operations

# %%
len([11, 22, 33, 44,55])
# Out:
# 5

# %%
[11, 12, 13] + [14, 15, 16]
# Out:
# [11, 12, 13, 14, 15, 16]

# %%
['Ni!'] * 3
# Out:
# ['Ni!', 'Ni!', 'Ni!']

# %%
3 in [11, 22, 33, 44,55]
# Out:
# False

# %%
for x in [11, 12, 13]: 
    print (x)
# Out:
# 11
# 12
# 13

# %%
str([11, 12]) + "30"
# Out:
# '[11, 12]30'

# %%
[11, 12] + list("30")
# Out:
# [11, 12, '3', '0']

# %% [markdown]
# Indexing, Slicing, and Matrixes

# %%
L = ['red', 'green', 'Blue!']

# %%
L[1]
# Out:
# 'green'

# %%
L[-1]
# Out:
# 'Blue!'

# %%
L[1:]
# Out:
# ['green', 'Blue!']

# %%
matrix = [[11, 12, 13], [14, 15, 16], [17, 18, 19]]

# %%
matrix[1]
# Out:
# [14, 15, 16]

# %%
matrix[1][1]
# Out:
# 15

# %%
matrix[2][0]
# Out:
# 17

# %%
matrix = [[11, 12, 13],
          [14, 15, 16],
          [17, 18, 19]]

# %%
matrix[1][1]
# Out:
# 15

# %% [markdown]
# Changing Lists In-Place

# %%
L = ['red', 'green', 'Blue!']
L[1] = 'black'
L
# Out:
# ['red', 'black', 'Blue!']

# %% [markdown]
# delete+insert

# %%
L[0:2] = ['pink', 'white']  
L
# Out:
# ['pink', 'white', 'Blue!']

# %%
L.append('help') 
L
# Out:
# ['pink', 'white', 'Blue!', 'help']

# %%
L.sort( )
L
# Out:
# ['Blue!', 'help', 'pink', 'white']

# %%
L = [11, 12]
L.extend([13,14,15]) 
L
# Out:
# [11, 12, 13, 14, 15]

# %%
L.pop( )
# Out:
# 15

# %%
L
# Out:
# [11, 12, 13, 14]

# %%
L.reverse( ) 
L
# Out:
# [14, 13, 12, 11]

# %%
L = []
L.append(11) 
L.append(12)
L
# Out:
# [11, 12]

# %%
L
['pink', 'white', 'Blue!', 'help']
# Out:
# ['pink', 'white', 'Blue!', 'help']

# %%
del L[1:]
L
# Out:
# []

# %%
L = ['FIVE', 'TWO', 'TEN']
L[1:] = []
L
# Out:
# ['FIVE']

# %%
L[0] = []
L
# Out:
# [[]]

# %% [markdown]
# Dictionaries

# %%
D1 = {} 
D2 = {'GREEN': 2, 'RED': 3} 
D3 = {'BLUE': {'BLACK': 1, 'WHITE': 2}}

# %%
D2.keys( )
# Out:
# dict_keys(['GREEN', 'RED'])

# %%
D2.values( )
# Out:
# dict_values([2, 3])

# %%
D2.copy( )
# Out:
# {'GREEN': 2, 'RED': 3}

# %%
D2.get(key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-8b6cdd53233b> in <module>
# ----> 1 D2.get(key)
#
# NameError: name 'key' is not defined

# %%
D2.update(D1)

# %%
D2.pop(key)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-0ed1f1c2c4af> in <module>
# ----> 1 D2.pop(key)
#
# NameError: name 'key' is not defined

# %%
len(D1)
# Out:
# 0

# %%
D2[key] = 42
del D2[key]
