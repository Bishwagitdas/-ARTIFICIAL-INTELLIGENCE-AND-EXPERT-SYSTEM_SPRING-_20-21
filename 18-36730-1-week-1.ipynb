# %% [markdown]
# BISHWAGIT DAS,ID: 18-36730-1,SEC: F,Week 1

# %% [markdown]
# number examples

# %%
a=34
b=3
a+b
# Out:
# 37

# %%
a*3
# Out:
# 102

# %%
a**3
# Out:
# 39304

# %%
print(a+b)
# Out:
# 37

# %%
a==b
# Out:
# False

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(7)
# Out:
# 2.6457513110645907

# %% [raw]
# string example

# %%
st='Bangladesh'
st
# Out:
# 'Bangladesh'

# %%
st[0]
# Out:
# 'B'

# %%
st[-1]
# Out:
# 'h'

# %%
st[9]
# Out:
# 'h'

# %%
len(st)
# Out:
# 10

# %%
st[0:4]
# Out:
# 'Bang'

# %%
st[:4]
# Out:
# 'Bang'

# %%
st[:-2]
# Out:
# 'Banglade'

# %%
st[2:]
# Out:
# 'ngladesh'

# %%
st+'ism'
# Out:
# 'Bangladeshism'

# %%
st*3
# Out:
# 'BangladeshBangladeshBangladesh'

# %%
st.find('glad')
# Out:
# 3

# %%
st.replace('lad','stdjk')
# Out:
# 'Bangstdjkesh'

# %%
st
# Out:
# 'Bangladesh'

# %%
st='w'+st[1:]
st
# Out:
# 'wangladesh'

# %%
st.upper()
# Out:
# 'WANGLADESH'

# %%
dir(st)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
name='bishwagit das'
name.split(' ')
# Out:
# ['bishwagit', 'das']

# %%
name='bishwagit das'
name.split(' ')[0]
# Out:
# 'bishwagit'

# %%
name='bishwagit das'
name.split(' ')[1]
# Out:
# 'das'

# %%
name='bishwagit das'
firstN,lastN=name.split(' ')
print(firstN)
print(lastN)
# Out:
# bishwagit
# das

# %% [markdown]
# spliting first name,last name

# %%
name='bishwagit kumar das'
firstN=name.split(' ')[0]
lastN=name.split(' ')[-1]
print(firstN)
print(lastN)
# Out:
# bishwagit
# das

# %%
help(name.split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the words in the string, using sep as the delimiter string.
#
#     sep
#       The delimiter according which to split the string.
#       None (the default value) means split according to any whitespace,
#       and discard empty strings from the result.
#     maxsplit
#       Maximum number of splits to do.
#       -1 (the default value) means no limit.

# %% [markdown]
# list examples

# %%
L=[12, 'glad', 89, 9.6]

# %%
L[:-1]
# Out:
# [12, 'glad', 89]

# %%
L[0]
# Out:
# 12

# %%
L+[18,90,5]
# Out:
# [12, 'glad', 89, 9.6, 18, 90, 5]

# %%
L
# Out:
# [12, 'glad', 89, 9.6]

# %% [markdown]
# LIST (Type-specific operation)

# %%
L.append('Desh')
L
# Out:
# [12,
#  'glad',
#  9.6,
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'BD',
#  'Desh',
#  'Desh',
#  'Desh']

# %%
L.append('BD')
L
# Out:
# [12,
#  'glad',
#  89,
#  9.6,
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'BD']

# %%
L.pop(2)
# Out:
# 89

# %%
L
# Out:
# [12, 'glad', 9.6, 'Desh', 'Desh', 'Desh', 'Desh', 'Desh', 'Desh', 'Desh', 'BD']

# %%
M=['DB','AA','CC']
M.sort()
M
# Out:
# ['AA', 'CC', 'DB']

# %%
M.reverse()
M
# Out:
# ['DB', 'CC', 'AA']

# %% [markdown]
# Bounding checking

# %%
L
# Out:
# [12,
#  'glad',
#  9.6,
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'Desh',
#  'BD',
#  'Desh',
#  'Desh',
#  'Desh']

# %%
L[8]
# Out:
# 'Desh'

# %% [markdown]
# NESTING

# %%
M=[[1,2,3],[4,5,6],[7,8,9]]
M
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [raw]
# ROW 2

# %%
M[1]
# Out:
# [4, 5, 6]

# %%
M[1][2]
# Out:
# 6

# %%
M[2][2]
# Out:
# 9

# %% [markdown]
# List Comprehension

# %%
col2=[row[1] for row in M]
col2
# Out:
# [2, 5, 8]

# %%
M
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
[row[1]+1 for row in M]
# Out:
# [3, 6, 9]

# %%
[row[1] for row in M if row[1]%2==0]
# Out:
# [2, 8]

# %%
diag=[M[i][i] for i in [0,1,2,]]
diag
# Out:
# [1, 5, 9]

# %%
doubles=[c*2 for c in 'spam']
doubles
# Out:
# ['ss', 'pp', 'aa', 'mm']

# %% [markdown]
# Dictionaries

# %%
D={'food':'spam','quantity':10,'color':'red'}

# %%
D['food']
# Out:
# 'spam'

# %%
D['quantity']+= 1 
D
# Out:
# {'food': 'spam', 'quantity': 14, 'color': 'red'}

# %%
D={}
D['name'] = 'Bishwagit'
D['id'] = '18-36730-1'
D['age'] = 23
D['department'] = 'CSE'
D
# Out:
# {'name': 'Bishwagit', 'id': '18-36730-1', 'age': 23, 'department': 'CSE'}

# %%
print (D['name'])
print (D['id'])
print (D['age'])
print (D['department'])
# Out:
# Bishwagit
# 18-36730-1
# 23
# CSE

# %% [markdown]
# NESTING REVISITED

# %%
rec = {'name': {'first': 'Bishwagit', 'last': 'Das'},
'id': ['18-36730-1', '18367301'],
'age': 23.5,
'department':['CSE','CS'] }

# %%
rec['name']
# Out:
# {'first': 'Bishwagit', 'last': 'Das'}

# %%
rec['name']['last']
# Out:
# 'Das'

# %%
rec['id']
# Out:
# ['18-36730-1', '18367301']

# %%
rec['age']
# Out:
# 23.5

# %%
rec['department']
