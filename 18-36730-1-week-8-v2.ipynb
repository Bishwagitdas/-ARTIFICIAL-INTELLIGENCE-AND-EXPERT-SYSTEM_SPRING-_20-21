# %% [markdown]
# BISHWAGIT DAS,18-36730-1,SEC:F WEEK-8

# %% [markdown]
# # Problem: Maximie f(x) = x^2 when x= 1 to 31

# %% [markdown]
# # Step 1: Initialize Population

# %%
[i for i in range(4)]
# Out:
# [0, 1, 2, 3]

# %%
import random
def initPopulation(n,b):
    p={}
    for i in range(n):
        s=[]
        for j in range(b):
            s.append(random.choice([0,1]))    
        p[i]=s
    return p

# %%
population=initPopulation(6,5)
population
# Out:
# {0: [0, 0, 1, 1, 1],
#  1: [1, 0, 1, 0, 0],
#  2: [1, 1, 0, 1, 1],
#  3: [0, 0, 0, 1, 0],
#  4: [0, 1, 1, 0, 0],
#  5: [1, 0, 1, 0, 1]}

# %% [markdown]
# # Step 2: Parent Selection

# %% [markdown]
# Fitness Calculation

# %%
[i for i in range(4,-1,-1)]
# Out:
# [4, 3, 2, 1, 0]

# %%
def getFitness(p):
    f=[]
    for k in p.keys():
        d = 0
        b = len(p[k])
        for i in range(b-1,-1,-1):
            d=d+p[k][i]*2**(4-i)
        f.append(d**2)
    return f

# %%
fitness = getFitness(population)
fitness
# Out:
# [49, 400, 729, 4, 144, 441]

# %% [markdown]
#  probability

# %%
total_fitness = sum(fitness)
prob = [round(f/total_fitness,3) for f in fitness]
prob
# Out:
# [0.028, 0.226, 0.413, 0.002, 0.081, 0.25]

# %%
def select_parent(n,fitness):
    total_fitness = sum(fitness)
    probabilities = [round(f/total_fitness,3) for f in fitness]
    parents = {}
    for i in range(n):
        r =random.choice(range(1,1001,1))/1000
        s = 0
        for j in range(len(probabilities)):
            s = s + probabilities[j]
            if(s>r):
                parents[i]=population[j]
                #print(population[j])
                break
    return parents

# %%
parents = select_parent(4,fitness)
parents
# Out:
# {0: [1, 1, 0, 1, 1],
#  1: [1, 0, 1, 0, 0],
#  2: [1, 0, 1, 0, 1],
#  3: [1, 1, 0, 1, 1]}

# %% [markdown]
# # Step 3: Crossover

# %%
cp = random.choice(range(1,5))
cp
# Out:
# 3

# %%
k = random.randint(0, 9) 
print("Crossover point :",k)
# Out:
# Crossover point : 8

# %%
parent1 = '10110000124532548756'    
parent2 = '01001745896587412365'

# %%
import random
def Crossover(parent1,parent2,point):
    p1,p2 = list(parent1),list(parent2) 
    for i in range(point,len(p1)):
        p1[i],p2[i] = p2[i],p1[i]       
    p1,p2 = ''.join(p1),''.join(p2)  
    return p1,p2
parent1 = '11001'    
parent2 = '11000'
print('Parent1:',parent1)
print('Parent2:',parent2)
point = random.randint(1,len(parent1))
print('Crossover Point:',point)
offspring1,offspring2 = Crossover(parent1,parent2,point)
print('Offspring1:',offspring1)        
print('Offspring2:',offspring2)
# Out:
# Parent1: 11001
# Parent2: 11000
# Crossover Point: 5
# Offspring1: 11001
# Offspring2: 11000

# %% [markdown]
# # Step 4: Select Survivor
# The selected survivors (solutions) will be added to population

# %%
import numpy as np

# %%
size = 25
n=6
pop_size= sum(range(n+1))
print(pop_size)
# Out:
# 21

# %%
def eval_fit(pop):
    fit_vals = []
    for i in range(len(pop)):
        fit_vals.append(np.sum(pop[i]))
        
    return np.array(fit_vals)
# Out:
#   File "<ipython-input-16-6f52815c377e>", line 6
#     return np.array(fit_vals
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
def rank_pop(pop):
    ranked =  [ pop[i] for i in np.argsort(-eval_fit(pop))]
    return ranked

# %%
def cross_pop(pop):
    new_pop = []
    for i in range(n):
        for j in range(i,n):
            x = np.random.randint(low=int(size/5),high=3*int(size/5))
            new_pop.append(np.concatenate([pop[i][:x],pop[j][x:]]))
    return new_pop

# %%
def mut_pop(pop,k):
    for i in range(len(pop)):
        x = np.random.randint(0,k)
        if(x==0):
            y = np.random.randint(0,size)
            pop[i][y] = (pop[i][y]+1) %2
    return pop

# %%
pop = []

for i in range(pop_size):    
    pop.append(np.random.randint(low=0,high=2, size=(size)))
m = 0
mut_prob = 3
best_fitn = np.amax(eval_fit(pop))

while(best_fitn < size and m<100):
        
    pop = rank_pop(pop)
    pop = cross_pop(pop)
    pop = mut_pop(pop,mut_prob)
    
    print("Generation: " + str(m))
    print(str(best_fitn) + " : " + str(100*best_fitn/size) + "%")
    best_fitn = np.amax(eval_fit(pop))
    m=m+1
  
print("\n")
print("Completed at generation: " + str(m))
print("fitness is: " + str(100*best_fitn/size) + "%")
pop = rank_pop(pop)
print("individual is: ")
pop[0]
